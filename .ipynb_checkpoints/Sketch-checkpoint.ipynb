# %%
img=cv2.imread('me.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x23CB14C5FA0>

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=416x416 at 0x23CB2631EE0>

# %%
image_inv = cv2.bitwise_not(gray_image)
display(Image.fromarray(image_inv))
# Out:
# <PIL.Image.Image image mode=L size=416x416 at 0x23CB14E81F0>

# %%
image_smooth = cv2.GaussianBlur(image_inv, (21, 21), 0)
display(Image.fromarray(image_smooth))
# Out:
# <PIL.Image.Image image mode=L size=416x416 at 0x23CB14E8250>

# %%
def dodge(gray_image, image_smooth):
  image_smooth_inv = 255 - image_smooth
  return cv2.divide(gray_image, image_smooth_inv, scale=256.0)

# %%
image_final = dodge(gray_image, image_smooth)
display(Image.fromarray(image_final))
# Out:
# <PIL.Image.Image image mode=L size=416x416 at 0x23C90E2DCD0>

# %%
display(Image.fromarray(img))
display(Image.fromarray(image_final))
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x23C90C1B070>
# <PIL.Image.Image image mode=L size=416x416 at 0x23CB14C5D00>
